# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import seaborn as sns
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV, Lasso
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score

# %% [markdown]
# A) Load and Clean Data
# --

# %%
data1 = pd.read_csv("../data/diagnosis.data", sep = '\t', header=None, encoding = 'utf-16')

# %%
print(data1.info())
print(data1.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       120 non-null    object
#  1   1       120 non-null    object
#  2   2       120 non-null    object
#  3   3       120 non-null    object
#  4   4       120 non-null    object
#  5   5       120 non-null    object
#  6   6       120 non-null    object
#  7   7       120 non-null    object
# dtypes: object(8)
# memory usage: 7.6+ KB
# None
#       0   1    2    3    4    5    6   7
# 0  35,5  no  yes   no   no   no   no  no
# 1  35,9  no   no  yes  yes  yes  yes  no
# 2  35,9  no  yes   no   no   no   no  no
# 3  36,0  no   no  yes  yes  yes  yes  no
# 4  36,0  no  yes   no   no   no   no  no

# %% [markdown]
# Temperature values need to be fixed by replacing , with .

# %%
data1[0] = data1[0].astype(str).str.replace(',', '.').astype(float)

# %%
# Rename columns for readability
data1.columns = ["Temperature", "Nausea", "Lumbar Pain", "Urine pushing", "Micturition pains", "Burning","Inflammation", "Nephritis"]

# %%
data1.head()
# Out:
#    Temperature Nausea Lumbar Pain Urine pushing Micturition pains Burning  \
# 0         35.5     no         yes            no                no      no
# 1         35.9     no          no           yes               yes     yes
# 2         35.9     no         yes            no                no      no
# 3         36.0     no          no           yes               yes     yes
# 4         36.0     no         yes            no                no      no
#
#   Inflammation Nephritis
# 0           no        no
# 1          yes        no
# 2           no        no
# 3          yes        no
# 4           no        no

# %% [markdown]
# B) Plotting decision tree.
# --
# Step 1: Map yes/no to 1/0 for all categorial columns.

# %%
categorical_cols = ["Nausea", "Lumbar Pain", "Urine pushing", "Micturition pains"]
data1[categorical_cols] = data1[categorical_cols].replace({'yes': 1, 'no': 0}).infer_objects(copy=False)
# Out:
# C:\Users\navya\AppData\Local\Temp\ipykernel_31572\2192458219.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data1[categorical_cols] = data1[categorical_cols].replace({'yes': 1, 'no': 0}).infer_objects(copy=False)

# %% [markdown]
# Step 2: Use label powerset approach by combining last two columns

# %%
data1['label'] = data1["Inflammation"].astype(str) + data1["Nephritis"].astype(str)
data1.head()
# Out:
#    Temperature  Nausea  Lumbar Pain  Urine pushing  Micturition pains Burning  \
# 0         35.5       0            1              0                  0      no
# 1         35.9       0            0              1                  1     yes
# 2         35.9       0            1              0                  0      no
# 3         36.0       0            0              1                  1     yes
# 4         36.0       0            1              0                  0      no
#
#   Inflammation Nephritis  label
# 0           no        no   nono
# 1          yes        no  yesno
# 2           no        no   nono
# 3          yes        no  yesno
# 4           no        no   nono

# %% [markdown]
# Step 3: We assign 1st 5 columns to X and label column to y.

# %%
X = data1.iloc[:, 0:5]  
y = data1['label'].astype(str)

# %% [markdown]
# Step 4: Training the decision tree . Default criterion is 'gini'.
# Source: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
classifier = DecisionTreeClassifier(random_state=42) 
classifier.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# Step 5: Plot decision tree. Source: https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html

# %%
plt.figure(figsize=(20,10))
plot_tree(classifier, filled=True, feature_names=X.columns.tolist(), class_names=classifier.classes_)
plt.title("Full Decision Tree")
plt.show()

# %% [markdown]
# C) Convert to IF-THEN rules using export_test
# --

# %%
rules = export_text(classifier, feature_names=X.columns.tolist())
print("IF-THEN Rules:\n")
print(rules)
# Out:
# IF-THEN Rules:
#
# |--- Lumbar Pain <= 0.50
# |   |--- Temperature <= 38.95
# |   |   |--- class: yesno
# |   |--- Temperature >  38.95
# |   |   |--- class: nono
# |--- Lumbar Pain >  0.50
# |   |--- Temperature <= 37.95
# |   |   |--- class: nono
# |   |--- Temperature >  37.95
# |   |   |--- Micturition pains <= 0.50
# |   |   |   |--- class: noyes
# |   |   |--- Micturition pains >  0.50
# |   |   |   |--- Urine pushing <= 0.50
# |   |   |   |   |--- class: noyes
# |   |   |   |--- Urine pushing >  0.50
# |   |   |   |   |--- class: yesyes

# %% [markdown]
# D) Prune Tree using Cost-Complexity Pruning.
# --

# %%
path = classifier.cost_complexity_pruning_path(X, y)
ccp_alphas = path.ccp_alphas[:-1]  # Skip the max alpha that prunes all leaves

# %% [markdown]
# We do cross validation to find best alpha using GridSearchCV.
# Source: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %%
param_grid = {'ccp_alpha': ccp_alphas}
grid_search = GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy'
)
grid_search.fit(X, y)

best_alpha = grid_search.best_params_['ccp_alpha']
best_tree = grid_search.best_estimator_
print("Best alpha: ",best_alpha)
# Out:
# Best alpha:  0.0

# %% [markdown]
# Best alpha is 0.0
# --
# Plot tree and print rules:

# %%
plt.figure(figsize=(20,10))
plot_tree(best_tree, filled=True, feature_names=X.columns.tolist(), class_names=best_tree.classes_)
plt.show()

# %%
# Print rules for pruned tree
pruned_rules = export_text(best_tree, feature_names=X.columns.tolist())
print("IF-THEN Rules (Pruned Tree):\n")
print(pruned_rules)
# Out:
# IF-THEN Rules (Pruned Tree):
#
# |--- Lumbar Pain <= 0.50
# |   |--- Temperature <= 38.95
# |   |   |--- class: yesno
# |   |--- Temperature >  38.95
# |   |   |--- class: nono
# |--- Lumbar Pain >  0.50
# |   |--- Temperature <= 37.95
# |   |   |--- class: nono
# |   |--- Temperature >  37.95
# |   |   |--- Micturition pains <= 0.50
# |   |   |   |--- class: noyes
# |   |   |--- Micturition pains >  0.50
# |   |   |   |--- Urine pushing <= 0.50
# |   |   |   |   |--- class: noyes
# |   |   |   |--- Urine pushing >  0.50
# |   |   |   |   |--- class: yesyes

# %% [markdown]
# Sources:
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html
